# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
data = files.upload()
# Out:
#      <input type="file" id="files-daf928ea-64bc-4940-bdac-47be3cc45002" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-daf928ea-64bc-4940-bdac-47be3cc45002">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("/content/london_housing_data_analysis.csv")

# %%
df
# Out:
#             date            area  average_price       code  houses_sold  \
# 0       1/1/1995  city of london          91449  E09000001         17.0
# 1       2/1/1995  city of london          82203  E09000001          7.0
# 2       3/1/1995  city of london          79121  E09000001         14.0
# 3       4/1/1995  city of london          77101  E09000001          7.0
# 4       5/1/1995  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544   9/1/2019         england         249942  E92000001      64605.0
# 13545  10/1/2019         england         249376  E92000001      68677.0
# 13546  11/1/2019         england         248515  E92000001      67814.0
# 13547  12/1/2019         england         250410  E92000001          NaN
# 13548   1/1/2020         england         247355  E92000001          NaN
#
#        no_of_crimes
# 0               NaN
# 1               NaN
# 2               NaN
# ...

# %%
df.isnull().sum()
# Out:
# date                0
# area                0
# average_price       0
# code                0
# houses_sold        94
# no_of_crimes     6110
# dtype: int64

# %%
df.count()
# Out:
# date             13549
# area             13549
# month            13549
# average_price    13549
# code             13549
# houses_sold      13455
# no_of_crimes      7439
# Year             13549
# dtype: int64

# %%
sns.heatmap(df.isnull())
plt.show()

# %%
df.dtypes
# Out:
# date              object
# area              object
# average_price      int64
# code              object
# houses_sold      float64
# no_of_crimes     float64
# dtype: object

# %%
df['date'] = pd.to_datetime(df['date'])
df
# Out:
#             date            area  month  average_price       code  \
# 0     1995-01-01  city of london      1          91449  E09000001
# 1     1995-02-01  city of london      2          82203  E09000001
# 2     1995-03-01  city of london      3          79121  E09000001
# 3     1995-04-01  city of london      4          77101  E09000001
# 4     1995-05-01  city of london      5          84409  E09000001
# ...          ...             ...    ...            ...        ...
# 13544 2019-09-01         england      9         249942  E92000001
# 13545 2019-10-01         england     10         249376  E92000001
# 13546 2019-11-01         england     11         248515  E92000001
# 13547 2019-12-01         england     12         250410  E92000001
# 13548 2020-01-01         england      1         247355  E92000001
#
#        houses_sold  no_of_crimes  Year
# 0             17.0           NaN  1995
# 1              7.0           NaN  1995
# 2             14.0           NaN  1995
# ...

# %%
df.dtypes
# Out:
# date             datetime64[ns]
# area                     object
# average_price             int64
# code                     object
# houses_sold             float64
# no_of_crimes            float64
# dtype: object

# %%
df['Year'] = df.date.dt.year
df
# Out:
#             date            area  average_price       code  houses_sold  \
# 0     1995-01-01  city of london          91449  E09000001         17.0
# 1     1995-02-01  city of london          82203  E09000001          7.0
# 2     1995-03-01  city of london          79121  E09000001         14.0
# 3     1995-04-01  city of london          77101  E09000001          7.0
# 4     1995-05-01  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544 2019-09-01         england         249942  E92000001      64605.0
# 13545 2019-10-01         england         249376  E92000001      68677.0
# 13546 2019-11-01         england         248515  E92000001      67814.0
# 13547 2019-12-01         england         250410  E92000001          NaN
# 13548 2020-01-01         england         247355  E92000001          NaN
#
#        no_of_crimes  Year
# 0               NaN  1995
# 1               NaN  1995
# ...

# %%
# Insert the 'Year' column at the 2nd position
df['Year'] = df.insert(2, 'Year', df.date.dt.year)

df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-04ff3a0b80c7> in <cell line: 0>()
#       1 # Insert the 'Year' column at the 2nd position
# ----> 2 df['Year'] = df.insert(2, 'Year', df.date.dt.year)
#       3
#       4 df
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    5156         if not allow_duplicates and column in self.columns:
#    5157             # Should this be a different kind of error??
# -> 5158             raise ValueError(f"cannot insert {column}, already exists")
#    5159         if not is_integer(loc):
#    5160             raise TypeError("loc must be int")
#
# ValueError: cannot insert Year, already exists

# %%
df.drop(columns = 'month',inplace = True)

# %%
df.drop(columns = 'month')
# Out:
#             date            area  average_price       code  houses_sold  \
# 0     1995-01-01  city of london          91449  E09000001         17.0
# 1     1995-02-01  city of london          82203  E09000001          7.0
# 2     1995-03-01  city of london          79121  E09000001         14.0
# 3     1995-04-01  city of london          77101  E09000001          7.0
# 4     1995-05-01  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544 2019-09-01         england         249942  E92000001      64605.0
# 13545 2019-10-01         england         249376  E92000001      68677.0
# 13546 2019-11-01         england         248515  E92000001      67814.0
# 13547 2019-12-01         england         250410  E92000001          NaN
# 13548 2020-01-01         england         247355  E92000001          NaN
#
#        no_of_crimes
# 0               NaN
# 1               NaN
# 2               NaN
# ...

# %%
df[df['no_of_crimes'] ==0].value_counts()
# Out:
# date        area            month  average_price  code       houses_sold  no_of_crimes
# 2001-01-01  city of london  1      284262         E09000001  24.0         0.0             1
# 2001-02-01  city of london  2      198137         E09000001  37.0         0.0             1
# 2007-12-01  city of london  12     464277         E09000001  11.0         0.0             1
# 2007-11-01  city of london  11     450831         E09000001  22.0         0.0             1
# 2007-10-01  city of london  10     456422         E09000001  19.0         0.0             1
#                                                                                          ..
# 2003-08-01  city of london  8      245449         E09000001  46.0         0.0             1
# 2003-07-01  city of london  7      260204         E09000001  48.0         0.0             1
# 2003-06-01  city of london  6      267208         E09000001  84.0         0.0             1
# ...

# %%
df1 = df[df['area'] == 'england']
df1
# Out:
#             date     area  month  average_price       code  houses_sold  \
# 13248 1995-01-01  england      1          53203  E92000001      47639.0
# 13249 1995-02-01  england      2          53096  E92000001      47880.0
# 13250 1995-03-01  england      3          53201  E92000001      67025.0
# 13251 1995-04-01  england      4          53591  E92000001      56925.0
# 13252 1995-05-01  england      5          53678  E92000001      64192.0
# ...          ...      ...    ...            ...        ...          ...
# 13544 2019-09-01  england      9         249942  E92000001      64605.0
# 13545 2019-10-01  england     10         249376  E92000001      68677.0
# 13546 2019-11-01  england     11         248515  E92000001      67814.0
# 13547 2019-12-01  england     12         250410  E92000001          NaN
# 13548 2020-01-01  england      1         247355  E92000001          NaN
#
#        no_of_crimes  Year
# 13248           NaN  1995
# 13249           NaN  1995
# ...

# %%
df1['year'] = df.date.dt.year
# Out:
# <ipython-input-77-881128034bc2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['year'] = df.date.dt.year

# %%
df.groupby('year')

# %%
df1.groupby('Year').average_price.max()
# Out:
# Year
# 1995     53901
# 1996     55755
# 1997     61564
# 1998     65743
# 1999     75071
# 2000     84191
# 2001     95992
# 2002    119982
# 2003    138985
# 2004    160330
# 2005    167244
# 2006    182031
# 2007    194764
# 2008    191750
# 2009    174136
# 2010    180807
# 2011    177335
# 2012    180129
# 2013    188544
# 2014    203639
# 2015    219582
# 2016    231922
# 2017    242628
# 2018    248620
# 2019    250410
# 2020    247355
# Name: average_price, dtype: int64

# %%
# prompt: what is the maximum and minm avg price per year in england

# Maximum average price per year in England
max_avg_price_england = df1.groupby('year').average_price.max()
print("Maximum average price per year in England:\n", max_avg_price_england)

# Minimum average price per year in England
min_avg_price_england = df1.groupby('year').average_price.min()
print("\nMinimum average price per year in England:\n", min_avg_price_england)
# Out:
# Maximum average price per year in England:
#  year
# 1995     53901
# 1996     55755
# 1997     61564
# 1998     65743
# 1999     75071
# 2000     84191
# 2001     95992
# 2002    119982
# 2003    138985
# 2004    160330
# 2005    167244
# 2006    182031
# 2007    194764
# 2008    191750
# 2009    174136
# 2010    180807
# 2011    177335
# 2012    180129
# 2013    188544
# 2014    203639
# 2015    219582
# 2016    231922
# 2017    242628
# 2018    248620
# 2019    250410
# 2020    247355
# Name: average_price, dtype: int64
#
# Minimum average price per year in England:
#  year
# 1995     52788
# 1996     52333
# 1997     55789
# 1998     61659
# 1999     65522
# 2000     75219
# 2001     84245
# 2002     96215
# 2003    121610
# 2004    139719
# 2005    158572
# 2006    166544
# 2007    181824
# 2008    165795
# 2009    159340
# 2010    174458
# 2011    173046
# 2012    174161
# 2013    176816
# 2014    188265
# 2015    202856
# 2016    220361
# 2017    231593
# 2018    240428
# ...

# %%
df.groupby('area').no_of_crimes.max()
# Out:
# area
# barking and dagenham      2049.0
# barnet                    2893.0
# bexley                    1914.0
# brent                     2937.0
# bromley                   2637.0
# camden                    4558.0
# city of london              10.0
# croydon                   3263.0
# ealing                    3401.0
# east midlands                NaN
# east of england              NaN
# enfield                   2798.0
# england                      NaN
# greenwich                 2853.0
# hackney                   3466.0
# hammersmith and fulham    2645.0
# haringey                  3199.0
# harrow                    1763.0
# havering                  1956.0
# hillingdon                2819.0
# hounslow                  2817.0
# inner london                 NaN
# islington                 3384.0
# kensington and chelsea    2778.0
# kingston upon thames      1379.0
# lambeth                   4701.0
# lewisham                  2813.0
# london                       NaN
# ...

# %%
df.groupby('area').no_of_crimes.min()
# Out:
# area
# barking and dagenham      1217.0
# barnet                    1703.0
# bexley                     860.0
# brent                     1850.0
# bromley                   1441.0
# camden                    2079.0
# city of london               0.0
# croydon                   2031.0
# ealing                    1871.0
# east midlands                NaN
# east of england              NaN
# enfield                   1635.0
# england                      NaN
# greenwich                 1513.0
# hackney                   1870.0
# hammersmith and fulham    1323.0
# haringey                  1536.0
# harrow                     937.0
# havering                  1130.0
# hillingdon                1445.0
# hounslow                  1529.0
# inner london                 NaN
# islington                 1871.0
# kensington and chelsea    1347.0
# kingston upon thames       692.0
# lambeth                   2381.0
# lewisham                  1675.0
# london                       NaN
# ...

# %%
df[df['average_price'] < 100000].area.value_counts()
# Out:
# area
# north east              112
# north west              111
# yorks and the humber    110
# east midlands            96
# west midlands            94
# england                  87
# barking and dagenham     85
# south west               78
# east of england          76
# newham                   72
# bexley                   64
# waltham forest           64
# lewisham                 62
# havering                 60
# south east               59
# greenwich                59
# croydon                  57
# enfield                  54
# sutton                   54
# hackney                  53
# redbridge                52
# southwark                48
# tower hamlets            47
# outer london             46
# hillingdon               44
# lambeth                  41
# hounslow                 41
# brent                    40
# london                   39
# merton                   35
# haringey                 33
# bromley                  33
# inner london             31
# ...

# %%
df
# Out:
#             date            area  month  average_price       code  \
# 0     1995-01-01  city of london      1          91449  E09000001
# 1     1995-02-01  city of london      2          82203  E09000001
# 2     1995-03-01  city of london      3          79121  E09000001
# 3     1995-04-01  city of london      4          77101  E09000001
# 4     1995-05-01  city of london      5          84409  E09000001
# ...          ...             ...    ...            ...        ...
# 13544 2019-09-01         england      9         249942  E92000001
# 13545 2019-10-01         england     10         249376  E92000001
# 13546 2019-11-01         england     11         248515  E92000001
# 13547 2019-12-01         england     12         250410  E92000001
# 13548 2020-01-01         england      1         247355  E92000001
#
#        houses_sold  no_of_crimes  year
# 0             17.0           NaN  1995
# 1              7.0           NaN  1995
# 2             14.0           NaN  1995
# ...
